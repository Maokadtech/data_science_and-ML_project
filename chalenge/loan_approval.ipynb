# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as pl
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
trd=pd.read_csv('loan_train.csv')
tsd=pd.read_csv('loan_test.csv')

# %%
trd.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
trd['Loan_Status']=label_encoder.fit_transform(trd['Loan_Status'])
trd['Education']=label_encoder.fit_transform(trd['Education'])
trd['Property_Area']=label_encoder.fit_transform(trd['Property_Area'])
trd['Gender']=label_encoder.fit_transform(trd['Gender'])
trd['Property_Area']=label_encoder.fit_transform(trd['SE'])

# %%
trd.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
trd['Gender'].replace('NaN',1,inplace=True)
trd['Married'].replace('No',0,inplace=True)

# %%
trd.head(24)
# Out:
#      Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0   LP001002       1      1.0          0          0            No
# 1   LP001003       1      1.0          1          0            No
# 2   LP001005       1      1.0          0          0           Yes
# 3   LP001006       1      1.0          0          1            No
# 4   LP001008       1      1.0          0          0            No
# 5   LP001011       1      1.0          2          0           Yes
# 6   LP001013       1      1.0          0          1            No
# 7   LP001014       1      1.0         3+          0            No
# 8   LP001018       1      1.0          2          0            No
# 9   LP001020       1      1.0          1          0            No
# 10  LP001024       1      1.0          2          0            No
# 11  LP001027       1      1.0          2          0           NaN
# 12  LP001028       1      1.0          2          0            No
# ...
